# %%
#import libraries
#Need to pip install selenium
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd
import matplotlib.pyplot as plt
import time
from datetime import date
from selenium.webdriver.common.keys import Keys

# %%
# Set up splinter
browser = Browser('chrome')

# base url
base_url = "https://offerup.com/search?"

# search parameters
# days_listed = 7
query = "honda+insight"
distance = 200

#full url
url = f"{base_url}q={query}&DISTANCE={distance}"

# %%
#visit site
browser.visit(url)

# %%
# Click on the element once it's found
browser.find_by_css('button[aria-label="Set my location currently set to"]').click()
time.sleep(1)
browser.find_by_css('div[class="MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-2 MuiGrid-justify-content-xs-space-between"]').click()
time.sleep(1)
browser.find_by_name('zipCode').type(Keys.BACKSPACE)
browser.find_by_name('zipCode').type(Keys.BACKSPACE)
browser.find_by_name('zipCode').type(Keys.BACKSPACE)
browser.find_by_name('zipCode').type(Keys.BACKSPACE)
browser.find_by_name('zipCode').type(Keys.BACKSPACE)
browser.find_by_name('zipCode').type("90501")
browser.find_by_css('button[aria-label="Apply"]').click()
browser.find_by_css('button[aria-live="polite"]').click()

# %%
# scroll down to load more results

scroll_count = 4

scroll_delay = 3

for _ in range(scroll_count):
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(scroll_delay)

# %%
# Parse HTML
html = browser.html

#create BS object from HTML
market_soup = soup(html, "html.parser")

# %%
# End browsing session
browser.quit()

# %%
import re


# Extract all the info, put into lists
titles_tag = market_soup.findAll(href=re.compile("item/detail"))
titles_list = [title.get('aria-label') for title in titles_tag]


href_list = [tag.get('href') for tag in titles_tag]


img_tag = market_soup.findAll(src=re.compile("images.offerup"))
img_list = [tag.get('src') for tag in img_tag]

# miles_div = market_soup.find_all('span', class_="x1lliihq x6ikm8r x10wlt62 x1n2onr6 xlyipyv xuxw1ft")
# miles_list = [mile.text.strip() for mile in miles_div]

# image_elems = market_soup.find_all('img', class_= "xt7dq6l xl1xv1r x6ikm8r x10wlt62 xh8yej3")
# image_list = [image.get('src') for image in image_elems]

# urls_elems = market_soup.find_all('a', class_= "x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x1heor9g x1lku1pv")
# urls_list = [url.get('href') for url in urls_elems]
# Out:
# ['https://images.offerup.com/sQJ5y2fsSxusyNMyQLyKtKeJ9Yk=/250x250/c764/c7649a7fb5ad490799e5c03cd4998b17.jpg',
#  'https://images.offerup.com/pjqK1lwv8Qr0c8AsJ46s3HQ3zXo=/1442x1442/ea09/ea09c217dc6742c883d3fbbcc297b272.jpg',
#  'https://images.offerup.com/1PmfB3YwEbYdPiqZyf-P8KAO0SA=/250x250/f072/f072738b2a8e4d8c841973f54658889a.jpg',
#  'https://images.offerup.com/Ejkq1-FII7Jl52eX9kQ3COaOLhg=/333x250/1bb9/1bb9548776174fbabd57b9b72a96fdd2.jpg',
#  'https://images.offerup.com/xwOkJNIGz6TUsu7WNyvqBfjBSRM=/250x250/2996/299610d487a64cadb0b4d26da70b127d.jpg',
#  'https://images.offerup.com/dBpGzTB8-0RlZ7VmJZpM9TqwziE=/333x250/3197/3197db15a8d64dae91d6001e47027810.jpg',
#  'https://images.offerup.com/l0hxSH7dK1uld1DFBvABzxpRWF4=/250x250/108c/108c6d0710534aaa89c56a5b6b6d6435.jpg',
#  'https://images.offerup.com/KkCIKT5E8glbPTXezkyc6QuGE6M=/250x250/ac48/ac48f5fbc5d040b49e0ce7c642fa9f10.jpg',
#  'https://images.offerup.com/iOIoa6H2-jSijPZJOyz1apXtmYI=/294x250/ad6d/ad6db2297d944dbcac16e7ee18b834bf.jpg',
#  'https://images.offerup.com/g5qiZps8pmbazijxkTdBDGpMLjU=/250x250/f9ab/f9abaa05026c45409a3f922be670851e.jpg',
#  'https://images.offerup.com/VQVzxfAepIV23Vw3WnQs9-UI6oE=/249x249/6b11/6b1126973f884105a6d959c5e2f90b30.jpg',
#  'https://images.offerup.com/IMKfgZyQbJyRSBxhX2ViVtXzrr4=/333x250/a7f2/a7f28ba9fa4e40fcb54798822a150561.jpg',
#  'https://images.offerup.com/9r5V10l2KqAndFmMW_KxRKeApDY=/250x250/8c52/8c52db7e5f4c4054aa446e99214634e5.jpg']

# %%
titles_list
# Out:
# [None,
#  '2012 Honda Insight $5,900  in Palmdale, CA',
#  '2019 Honda Insight $18,999 96k miles in Banning, CA',
#  '2010 Honda Insight $1,000  in El Cajon, CA',
#  '2020 Honda Insight Call for details 45k miles in Montclair, CA',
#  '2013 Honda Insight $8,000 148k miles in Montebello, CA',
#  '2013 Honda Insight $13,900 43k miles in Stevenson Ranch, CA',
#  '2011 Honda Insight $4,900 212k miles in Los Angeles, CA',
#  '2010 Honda Insight $8,995 98k miles in Los Angeles, CA',
#  '2011 Honda Insight $13,999 15k miles in Escondido, CA',
#  '2022 Honda Insight $23,888 25k miles in Bellflower, CA',
#  '2019 Honda Insight $18,999 96k miles in Fontana, CA',
#  '2020 Honda Insight $22,880 25k miles in Garden Grove, CA',
#  '2011 Honda Insight $13,999 15k miles in Escondido, CA',
#  '2021 Honda Insight $24,500 29k miles in Ontario, CA',
#  '2010 Honda Insight $8,995 98k miles in Los Angeles, CA',
#  '2010 Honda Insight $5,500 185k miles in Los Angeles, CA',
#  '2010 Honda Insight $5,500  in Fontana, CA',
#  '2021 Honda Insight $17,995 95k miles in Fontana, CA',
#  '2020 Honda Insight $18,880 69k miles in Garden Grove, CA',
#  '2011 Honda Insight $6,500  in Arcadia, CA',
#  '2019 Honda Insight $16,266 128k miles in Lancaster, CA',
#  '2022 Honda Insight $18,777 57k miles in Riverside, CA',
#  '2019 Honda Insight $18,999 96k miles in Fontana, CA',
#  '2021 Honda Insight $17,995 95k miles in Fontana, CA',
#  '2010 Honda Insight $6,900 128k miles in Rancho Cucamonga, CA',
#  '2021 Honda Insight $19,700 82k miles in Orange, CA',
#  '2010 Honda Insight $3,500 227k miles in San Diego, CA',
#  '2012 Honda Insight $7,500 95k miles in Vista, CA',
#  '2019 Honda Insight $18,999 96k miles in Banning, CA',
#  'Hondas insight  $5,500 135k miles in Los Angeles, CA',
#  '2019 Honda Insight $17,000  in Whittier, CA',
#  '2021 Honda Insight Call for details 96k miles in Pomona, CA',
#  '2010 Honda Insight LX $5,995 172k miles in Oceanside, CA',
#  '2010 Honda Insight $3,650  in El Centro, CA',
#  '2013 Honda Insight $5,400 160k miles in San Diego, CA',
#  '2022 Honda Insight $17,900 34k miles in Palmdale, CA',
#  '2010 Honda Insight $9,999 91k miles in San Bernardino, CA',
#  '2019 Honda Insight $16,995 55k miles in Bakersfield, CA',
#  '2019 Honda Insight $13  in Irwindale, CA',
#  '2019 Honda Insight $15,477 91k miles in Los Angeles, CA',
#  '2017 Subaru WRX $18,500 50k miles in Los Angeles, CA',
#  '2014 Honda Insight $12,000 79k miles in Buena Park, CA',
#  '2010 Honda Insight $6,800 127k miles in Laguna Niguel, CA',
#  '2010 Honda Insight $50  in Menifee, CA',
#  'Auto Car Steering Wheel Tray for Honda Civic Accord CR-v Pilot Odyssey Hatchback HR-v Fit Passport Truck Accessories 2000-2023,for Laptop, Tablet, iPa $10  in Diamond Bar, CA',
#  '2021 Honda Insight $17,495  in Moreno Valley, CA',
#  '2012 Honda Insight $700  in Garden Grove, CA',
#  '2021 Honda Insight $17,495  in Moreno Valley, CA',
#  '2021 Honda Insight $17,495  in Moreno Valley, CA',
#  '2021 Honda Insight $20,995 104k miles in El Monte, CA',
#  '2010 Honda Insight $5,500 185k miles in Los Angeles, CA',
#  '2013 Honda Insight $8,000  in Huntington Beach, CA',
#  '2019 Honda Insight $17,000 41k miles in Lawndale, CA',
#  '2019 Honda Insight $18,000 35k miles in Lynwood, CA',
#  '2021 Honda Insight Call for details 107k miles in Pomona, CA',
#  '2012 Honda Insight $7,600 140k miles in Gardena, CA',
#  '2019 Honda Insight $18,999 96k miles in Banning, CA',
#  '2019 Honda Insight $17,000 41k miles in Lawndale, CA',
#  '2010 Honda Insight $5,995  in Fountain Valley, CA',
#  '2019 Honda Insight $18,000  in Riverside, CA',
#  '2020 Honda Insight $29,000 25k miles in San Diego, CA',
#  '2021 Honda Insight $24,500 29k miles in Ontario, CA',
#  '2022 Honda Insight $27,500 22k miles in Lake Forest, CA',
#  '2019 Honda Insight $15,500 104k miles in Los Angeles, CA',
#  '2013 Honda Insight $8,000 138k miles in Los Angeles, CA',
#  '2010 Honda Insight $5,900 157k miles in Fontana, CA',
#  '2019 Honda Insight $16,995 55k miles in Bakersfield, CA',
#  '2019 Honda Insight $18,000 34k miles in Burbank, CA',
#  '2022 Honda Insight $50  in Los Angeles, CA',
#  '2011 Honda Accord Civic Pilot CRV Hybrid Insight Fit HRV Passport Element Crosstour Toyota Corolla Camry Prius RAV4 Mazda Nissan Avalon Kia Hyundai Si $7,900  in San Gabriel, CA',
#  '2010 Honda Insight $5,000 200k miles in West Los Angeles, CA',
#  '2020 Honda Insight $22,880 25k miles in Garden Grove, CA',
#  '2019 Honda Insight $100  in Santa Ana, CA',
#  '2010 Honda Insight $7,000  in San Pedro, CA',
#  '2011 Honda Insight $200  in Jamul, CA',
#  '2010 Honda Insight $6,995  in Fountain Valley, CA',
#  '2014 Honda Insight $11,450 107k miles in Rancho Suey, CA',
#  '2010 Honda Insight $4,000  in Los Angeles, CA',
#  '2000 Honda Insight $1  in Los Angeles, CA',
#  '2019 Honda inside lower bumper grill $85  in Compton, CA',
#  '2012 Honda Insight $8,500 90k miles in Los Angeles, CA',
#  'Honda   $1,234  in Bakersfield, CA',
#  '2010 Honda Insight $5,300 85k miles in Fontana, CA',
#  '2006 Honda Insight $5,999 75k miles in Thousand Oaks, CA',
#  '2010 Honda Insight $6,500 165k miles in Los Angeles, CA',
#  '2001 Honda Insight $4,000 227k miles in Fountain Valley, CA',
#  '2010 Honda Insight $3,900  in Chula Vista, CA',
#  '2021 Honda Insight Call for details 100k miles in Pomona, CA',
#  '2021 Honda Insight Call for details 109k miles in Pomona, CA',
#  '2013 Honda Insight $6,395  in Fountain Valley, CA',
#  '2012 Honda Insight $7,300 51k miles in Anaheim, CA',
#  '2014 Honda Insight $8,500 83k miles in Los Angeles, CA',
#  '2022 Honda Insight $250  in El Cajon, CA',
#  '2010 Honda Insight $4,500  in Adelanto, CA',
#  'Cabin Air Filter For Honda Fits Civic Insight Clarity Fit, CRV And  Xr-z See All Pictures For Fitment Years Ablo Español  $18  in Lakewood, CA',
#  'Honda Insight $35  in Bakersfield, CA',
#  '2010/2011 Honda Insight Lift Gate $380  in Compton, CA',
#  '2011 Honda Insight $550  in Los Angeles, CA',
#  '2010 Honda Insight $4,800  in San Gabriel, CA',
#  '2014 Honda Insight $19,000  in Lancaster, CA',
#  'Honda Insight  $31,000  in Woodville, CA',
#  'Honda $25  in La Puente, CA',
#  'Honda $15  in La Puente, CA',
#  '2010 Honda Insight . Cling  $4,500  in Chula Vista, CA',
#  '2019 Honda Insight $26,000 67k miles in San Diego, CA',
#  '2019 Honda Insight $15,000 78k miles in Victorville, CA',
#  'Two used tires for Honda Insight or Toyota Prius or smaller cars $100  in Victorville, CA',
#  '2010 Honda Insight $4,995  in Los Angeles, CA',
#  '2000 Honda Insight $995 150k miles in San Marcos, CA',
#  'Honda Insight 2014 Cluster Plus A/C controls $140  in Irvine, CA',
#  '2021 Honda Insight $25,900 24k miles in El Cajon, CA',
#  'Civic 98 $1  in Whittier, CA',
#  'Honda Insight Hybrid $22,000 10k miles in Los Angeles, CA',
#  'Honda- Accord Civic Del Sol CRV Insight Prelude S2000 Pilot $40  in San Bernardino, CA',
#  '2001 Honda Insight $7,996 202k miles in City Of Industry, CA',
#  '2010 Honda Insight $30  in Los Angeles, CA',
#  '2010 Honda Insight $3,000  in Tijuana, MX',
#  '2011 Honda Insight $6,500 141k miles in Lawndale, CA',
#  'Inverter Y Converter  Para Honda Civic Accord Battery Hybrid  $500  in Garden Grove, CA',
#  '2010 Honda Insight $3,500 186k miles in Victorville, CA',
#  '2010 Honda Insight $5,900 71k miles in Long Beach, CA',
#  '2020 Honda Insight $31,000 40k miles in Woodville, CA',
#  '2010 Honda Insight $4,500 170k miles in San Diego, CA',
#  '2002 Honda Insight $4,500  in Riverside, CA',
#  '2010 Honda Insight $2,800 223k miles in Spring Valley, CA']

#  'https://images.offerup.com/LaJCNCjPoiHCuYjMsjGFIRG2Q_U=/250x250/f4ff/f4ff86ca918947e59ade58ed92cd86b1.jpg',
#  'https://images.offerup.com/2W9krCPrILzN7vgW3BDBQ3YR7JM=/250x250/c075/c075537caaff4ba9ad46c89cffb1ad50.jpg',
#  'https://images.offerup.com/0jDpfGfCdYXY_qGKwaJCwOeGKi0=/333x250/c8a9/c8a9878931594b2fb45de69ea4e924a9.jpg',
#  'https://images.offerup.com/qvmqhH1_XvXHff4Snsduv_oTPL0=/250x250/49b8/49b8f526ca0b40eeb8ce06bf3a0a62c7.jpg',
#  'https://images.offerup.com/EFff4MtdRqYCWiJLZs6j9pH0fNw=/250x250/321e/321eb766068f44e4a5f7f214df0a2f89.jpg',
#  'https://images.offerup.com/K7FChKnvPdSgcXiaS1-tZjndEgY=/250x250/d84b/d84b6042766a4784adf1eb737a87dca7.jpg',
#  'https://images.offerup.com/l0hxSH7dK1uld1DFBvABzxpRWF4=/250x250/108c/108c6d0710534aaa89c56a5b6b6d6435.jpg',
#  'https://images.offerup.com/KkCIKT5E8glbPTXezkyc6QuGE6M=/250x250/ac48/ac48f5fbc5d040b49e0ce7c642fa9f10.jpg',
#  'https://images.offerup.com/iOIoa6H2-jSijPZJOyz1apXtmYI=/294x250/ad6d/ad6db2297d944dbcac16e7ee18b834bf.jpg',
#  'https://images.offerup.com/g5qiZps8pmbazijxkTdBDGpMLjU=/250x250/f9ab/f9abaa05026c45409a3f922be670851e.jpg',
#  'https://images.offerup.com/VQVzxfAepIV23Vw3WnQs9-UI6oE=/249x249/6b11/6b1126973f884105a6d959c5e2f90b30.jpg',
#  'https://images.offerup.com/IMKfgZyQbJyRSBxhX2ViVtXzrr4=/333x250/a7f2/a7f28ba9fa4e40fcb54798822a150561.jpg',
#  'https://images.offerup.com/9r5V10l2KqAndFmMW_KxRKeApDY=/250x250/8c52/8c52db7e5f4c4054aa446e99214634e5.jpg']

# %%
# regex to filter
pattern = re.compile(r'[a-zA-Z ]+[,]\s[A-Z][A-Z]')
miles_pattern = re.compile(r'([0-9.]+)[K]? miles')

# initialize empty list
miles_list2 = []

#iterate through the original mileage entries
for item in miles_list:
    # miles_list2.append(item)

    if pattern.match(item) and len(miles_list2) >= 1 and pattern.match(miles_list2[-1]):
        miles_list2.append('0K miles')
        miles_list2.append(item)

    elif len(item) == 0 and pattern.match(miles_list2[-1]) and len(miles_list2) >=1:
        miles_list2.append('0K miles')

    elif len(miles_list2) >= 1 and pattern.match(miles_list2[-1]) and miles_pattern.match(item) == None:
        miles_list2.append('0K miles')

    else:
        miles_list2.append(item)

# %%
prices_list
# Out:
# ['$3,950',
#  '$6,400',
#  '$4,500',
#  '$11,900',
#  '$15,500',
#  '$5,800',
#  '$11,900',
#  '$4,900',
#  '$4,500',
#  '$6,600',
#  '$2,500',
#  '$4,000',
#  '$4,000',
#  '$6,800',
#  '$6,900',
#  '$16,199',
#  '$1',
#  '$4,500',
#  '$4,999',
#  '$16,900',
#  '$16,700',
#  '$24,499',
#  '$7,600',
#  '$18,800',
#  '$9,900',
#  '$21,499',
#  '$5,900',
#  '$250',
#  '$5,000',
#  '$5,898',
#  '$4,000',
#  '$555',
#  '$3,650',
#  '$10,900',
#  '$4,000',
#  '$555',
#  '$10,300',
#  '$555',
#  '$4,050',
#  '$14,800',
#  '$7,300',
#  '$18,000',
#  '$8,000',
#  '$4,700',
#  '$1,500',
#  '$18,900',
#  '$8,999',
#  '$3,500',
#  '$18,800',
#  '$4,500',
#  '$9,800',
#  '$6,800',
#  '$7,900',
#  '$8,500',
#  '$4,999',
#  '$7,000',
#  '$4,000',
#  '$4,000',
#  '$5,990',
#  '$8,500',
#  '$14,550',
#  '$4,000',
#  '$8,000',
#  '$7,800',
#  '$7,500',
#  '$12,000',
#  '$5,500',
#  '$22,961',
#  '$18,299',
#  '$20,000',
#  '$7,900',
#  '$24,100',
#  '$13,000',
#  '$6,900',
#  '$100',
#  '$4,500',
#  '$500',
#  '$32,981',
#  '$19,800',
#  '$17,488',
#  '$2,400',
#  '$5,000',
#  '$8,000',
#  '$15,000',
#  '$12,150',
#  '$17,000',
#  '$450',
#  '$6,000',
#  '$16,500',
#  '$6,300',
#  '$18,000',
#  '$13,600',
#  '$10,800',
#  '$14,200',
#  '$1,234',
#  '$4,150',
#  '$650',
#  '$8,000',
#  '$13,500',
#  '$22,999',
#  '$6,800',
#  '$10,500',
#  '$7,500',
#  '$26,000',
#  '$18,350',
#  '$12,888',
#  '$19,775',
#  '$9,900',
#  '$6,899',
#  '$19,500',
#  '$11,910',
#  '$10,500',
#  '$6,000',
#  '$12,900',
#  '$550',
#  '$12,500',
#  '$99',
#  '$4,000',
#  '$145',
#  '$12,000']

# %%
# Clean Location and Miles Data
miles_pattern_miles = r'([0-9.]+)[K]? miles'
miles_pattern_km = r'(\d+)K km'
location_pattern = r'[a-zA-Z ]+[,]\s[A-Z][A-Z]'

miles_clean = []
locations_clean =[]

for item in miles_list2:

    match_miles_km = re.search(miles_pattern_km, item)

    match_mileage_miles = re.search(miles_pattern_miles, item)

    match_location = re.search(location_pattern, item)

    if match_miles_km or match_mileage_miles or match_location:
        if match_miles_km:
            miles_clean.append(int(match_miles_km.group(1)) *1000)

        if match_mileage_miles:
            miles_clean.append(int(float(match_mileage_miles.group(1))) *1000)
            # print(match_mileage_miles)
            # print(int(float(match_mileage_miles.group(1))) *1000)

        if match_location:
            locations_clean.append(item)
            print(match_location)
            print(item)
# Out:
# <re.Match object; span=(0, 17), match='San Francisco, CA'>
# San Francisco, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0, 11), match='Fremont, CA'>
# Fremont, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0, 14), match='Carmichael, CA'>
# Carmichael, CA
# <re.Match object; span=(0, 13), match='Elk Grove, CA'>
# Elk Grove, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0, 12), match='Stockton, CA'>
# Stockton, CA
# <re.Match object; span=(0, 11), match='Rocklin, CA'>
# Rocklin, CA
# <re.Match object; span=(0, 12), match='Petaluma, CA'>
# Petaluma, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0,
CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 11), match='Concord, CA'>
# Concord, CA
# <re.Match object; span=(0, 9), match='Tracy, CA'>
# Tracy, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 19), match='West Sacramento, CA'>
# West Sacramento, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 18), match='Rancho Cordova, CA'>
# Rancho Cordova, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 12), match='Stockton, CA'>
# Stockton, CA
# <re.Match object; span=(0, 14), match='Union City, CA'>
# Union City, CA
# <re.Match object; span=(0, 15), match='Santa Clara, CA'>
# Santa Clara, CA
# <re.Match object; span=(0, 9), match='Sunol, CA'>
# Sunol, CA
# <re.Match object; span=(0, 12), match='Stockton, CA'>
# Stockton, CA
# <re.Match object; span=(0, 11), match='Manteca, CA'>
# Manteca, CA
# <re.Match object; span=(0, 11), match='Clayton, CA'>
# Clayton, CA
# <re.Match object; span=(0, 11), match='Manteca, CA'>
# Manteca, CA
# <re.Match object; span=(0, 11), match='Oakland, CA'>
# Oakland, CA
# <re.Match object; span=(0, 15), match='Santa Clara, CA'>
# Santa Clara, CA
# <re.Match object; span=(0, 12), match='Milpitas, CA'>
# Milpitas, CA
# <re.Match object; span=(0, 18), match='Citrus Heights, CA'>
# Citrus Heights, CA
# <re.Match object; span=(0, 12), match='Millbrae, CA'>
# Millbrae, CA
# <re.Match object; span=(0, 11), match='Willows, CA'>
# Willows, CA
# <re.Match object; span=(0, 13), match='Roseville, CA'>
# Roseville, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0, 12), match='San Jose, CA'>
# San Jose, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 11), match='Concord, CA'>
# Concord, CA
# <re.Match object; span=(0, 15), match='Watsonville, CA'>
# Watsonville, CA
# <re.Match object; span=(0, 9), match='Tracy, CA'>
# Tracy, CA
# <re.Match object; span=(0, 17), match='San Francisco, CA'>
# San Francisco, CA
# <re.Match object; span=(0, 12), match='Richmond, CA'>
# Richmond, CA
# <re.Match object; span=(0, 18), match='Rancho Cordova, CA'>
# Rancho Cordova, CA
# <re.Match object; span=(0, 14), match='Sacramento, CA'>
# Sacramento, CA
# <re.Match object; span=(0, 10), match='Newark, CA'>
# Newark, CA
# <re.Match object; span=(0, 12), match='Stockton, CA'>
# Stockton, CA

# %%
# Make Prices into Integer
prices_clean = []

for price in prices_list:
    if price == 'Free':
        prices_clean.append(0)
    else:
        prices_clean.append(int(re.sub(r'[$,]','', price)))

# %%
# Make URLS full url
urls_clean = []

for url in urls_list:
    urls_clean.append('https://www.facebook.com' + url)

# %%
miles_list2
# Out:
# ['Log In',
#  'Log In',
#  'Notify Me',
#  'Create new listing',
#  'Sort by',
#  'Delivery method: Local pickup',
#  'Condition',
#  'Date listed',
#  'Availability',
#  'San Francisco · 40 mi',
#  'Filters',
#  'Notify Me',
#  'San Francisco, CA',
#  '165K miles',
#  'San Jose, CA',
#  '125K miles',
#  'Fremont, CA',
#  '183K miles',
#  'San Jose, CA',
#  '110K miles',
#  'Carmichael, CA',
#  '49K miles',
#  'Elk Grove, CA',
#  '159K miles',
#  'San Jose, CA',
#  '110K miles',
#  'Stockton, CA',
#  '136K miles',
#  'Rocklin, CA',
#  '164K miles',
#  'Petaluma, CA',
#  '134K miles',
#  'San Jose, CA',
#  '271K miles',
#  'San Francisco, CA',
#  '0K miles',
#  'Oakland, CA',
#  '124K miles',
#  'San Francisco, CA',
#  '183K miles',
#  'Modesto, CA',
#  '108K miles',
#  'Sacramento, CA',
#  '31K miles',
#  'Salida, CA',
#  '0K miles',
#  'San Jose, CA',
#  '205K miles',
#  'Sacramento, CA',
#  '173K miles',
#  'Antioch, CA',
#  '46K miles',
#  'Roseville, CA',
#  '28K miles',
#  'San Rafael, CA',
#  '37K miles',
#  'Sacramento, CA',
#  '52K miles',
#  'Roseville, CA',
#  '21K miles',
#  'Santa Clara, CA',
#  '55K miles',
#  'Sacramento, CA',
#  '39K miles',
#  'North Highlands, CA',
#  '188K miles',
#  'San Francisco, CA',
#  '170K miles',
#  'San Francisco, CA',
#  '9K miles',
#  'Sonoma, CA',
#  '180K miles',
#  'Citrus Heights, CA',
#  '22K miles',
#  'Sacramento, CA',
#  '0K miles',
#  'Petaluma, CA',
#  '215K miles',
#  'Millbrae, CA',
#  '105K miles',
#  'Concord, CA',
#  '0K miles',
#  'Sacramento, CA',
#  '0K miles',
#  'San Jose, CA',
#  '85K miles',
#  'Sacramento, CA',
#  '0K miles',
#  'Sacramento, CA',
#  '179K miles',
#  'Modesto, CA',
#  '45K miles',
#  'Daly City, CA',
#  '188K miles',
#  'Tracy, CA',
#  '38K miles',
#  'Brisbane, CA',
#  '117K miles',
#  'Los Angeles, CA',
#  '210K miles',
#  'Redwood City, CA',
#  '209K miles',
#  'Stockton, CA',
#  '9K miles',
#  'Milpitas, CA',
#  '98K miles',
#  'San Jose, CA',
#  '0K miles',
#  'Fremont, CA',
#  '38K miles',
#  'Portola Valley, CA',
#  '257K miles',
#  'Sacramento, CA',
#  '133K miles',
#  'Fremont, CA',
#  '205K miles',
#  'Sacramento, CA',
#  '95K miles',
#  'San Jose, CA',
#  '91K miles',
#  'Los Angeles, CA',
#  '143K miles',
#  'Tracy, CA',
#  '112K miles · Dealership',
#  'San Mateo, CA',
#  '185K miles',
#  'Fairfield, CA',
#  '155K miles',
#  'Sacramento, CA',
#  '139K miles',
#  'Sacramento, CA',
#  '105K miles',
#  'Hayward, CA',
#  '37K miles',
#  'Los Angeles, CA',
#  '0K miles',
#  'West Sacramento, CA',
#  '156K miles',
#  'Menlo Park, CA',
#  '100K miles',
#  'San Jose, CA',
#  '91K miles',
#  'Sacramento, CA',
#  '59K miles',
#  'San Jose, CA',
#  '190K miles',
#  'Hayward, CA',
#  '61K miles',
#  'San Jose, CA',
#  '47K miles',
#  'Orangevale, CA',
#  '22K miles',
#  'Sacramento, CA',
#  '145K miles',
#  'Milpitas, CA',
#  '17K miles',
#  'Sacramento, CA',
#  '11K miles',
#  'Sacramento, CA',
#  '138K miles',
#  'Sacramento, CA',
#  '0K miles',
#  'Pittsburg, CA',
#  '100K miles',
#  'Concord, CA',
#  '50K miles · Dealership',
#  'Oakland, CA',
#  '21K miles',
#  'Concord, CA',
#  '19K miles',
#  'Newark, CA',
#  '68K miles',
#  'Campbell, CA',
#  '0K miles',
#  'San Mateo, CA',
#  '157K miles',
#  'Union City, CA',
#  '110K miles',
#  'Lodi, CA',
#  '49K miles',
#  'Sacramento, CA',
#  '123K miles',
#  'Sacramento, CA',
#  '67K miles',
#  'Concord, CA',
#  '0K miles',
#  'Tracy, CA',
#  '97K miles',
#  'Sacramento, CA',
#  '17K miles',
#  'West Sacramento, CA',
#  '142K miles',
#  'Sacramento, CA',
#  '38K miles',
#  'Rancho Cordova, CA',
#  '63K miles',
#  'Sacramento, CA',
#  '122K miles',
#  'Stockton, CA',
#  '83K miles',
#  'Union City, CA',
#  '40K miles',
#  'Santa Clara, CA',
#  '187K miles',
#  'Sunol, CA',
#  '115K miles',
#  'Stockton, CA',
#  '121K miles',
#  'Manteca, CA',
#  '184K miles',
#  'Clayton, CA',
#  '28K miles',
#  'Manteca, CA',
#  '154K miles',
#  'Oakland, CA',
#  '84K miles',
#  'Santa Clara, CA',
#  '150K miles',
#  'Milpitas, CA',
#  '37K miles',
#  'Citrus Heights, CA',
#  '53K miles',
#  'Millbrae, CA',
#  '49K miles',
#  'Willows, CA',
#  '87K miles',
#  'Roseville, CA',
#  '68K miles',
#  'San Jose, CA',
#  '120K miles',
#  'San Jose, CA',
#  '4K miles',
#  'Sacramento, CA',
#  '43K miles',
#  'Concord, CA',
#  '86K miles',
#  'Watsonville, CA',
#  '212K miles',
#  'Tracy, CA',
#  '117K miles',
#  'San Francisco, CA',
#  '0K miles',
#  'Richmond, CA',
#  '78K miles',
#  'Rancho Cordova, CA',
#  '999K miles',
#  'Sacramento, CA',
#  '81K miles',
#  'Newark, CA',
#  '0K miles',
#  'Stockton, CA',
#  '55K miles',
#  'Log in or sign up for Facebook to connect with friends, family and people you know.',
#  'Log In',
#  'Create new account']

# %%
# add all values to a list of dictionaries
vehicles_list = []

for i, item in enumerate(titles_list):
    cars_dict = {}
    first_gen = False
    insight = False
    parts = False
    years = ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "1st", "first gen"]

    #Checks if any cars are 2000 - 2006
    if any(x in titles_list[i] for x in years):
        first_gen = True

    #Checks if car listing is for parts
    if "part" in titles_list[i].lower():
        parts = True

    #Checks if insight is actually in the title
    if "insight" in titles_list[i].lower():
        insight = True

    #Splits up the City and State from location
    city = locations_clean[i].split(', ')[0]
    state = locations_clean[i].split(', ')[-1]



    # Map out key value pairs
    cars_dict["date"] = date.today()
    cars_dict["title"] = titles_list[i]
    cars_dict["price"] = prices_clean[i]
    cars_dict["city"] = city
    cars_dict["state"] = state
    cars_dict["mileage"] = miles_clean[i]
    cars_dict["url"] = urls_clean[i]
    cars_dict["image"] = image_list[i]
    cars_dict["insight"] = insight
    cars_dict["first_gen"] = first_gen
    cars_dict["parts"] = parts
    cars_dict["site"] = "fb"
    vehicles_list.append(cars_dict)

# %%
vehicles_list
# Out:
# [{'date': datetime.date(2024, 3, 25),
#   'title': '2002 Honda insight Hybrid Hatchback 2D',
#   'price': 3950,
#   'city': 'San Francisco',
#   'state': 'CA',
#   'mileage': 165000,
#   'url': 'https://www.facebook.com/marketplace/item/1492382191345101/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6

#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2011 Honda insight LX Hatchback 4D',
#   'price': 5898,
#   'city': 'Sonoma',
#   'state': 'CA',
#   'mileage': 180000,
#   'url': 'https://www.facebook.com/marketplace/item/376340201940120/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/433960589_10232514854710879_1798479801196545823_n.jpg?stp=c99.0.260.260a_dst-jpg_p261x260&_nc_cat=109&ccb=1-7&_nc_sid=5f2048&_nc_ohc=48dbxfKSFeoAX9gnWXM&_nc_ht=scontent-lax3-1.xx&oh=00_AfAd1KZ6OOZsoxT5KGcmutYQB-alClDSTGNbqMOoAc4-5g&oe=66071295',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2003 Honda insight Hatchback 2D',
#   'price': 4000,
#   'city': 'Citrus Heights',
#   'state': 'CA',
#   'mileage': 22000,
#   'url': 'https://www.facebook.com/marketplace/item/1401769057369811/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/434212312_349399721432590_2158011878392258202_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=101&ccb=1-7&_nc_sid=5f2048&_nc_ohc=60_rc2tpsLkAX9N0fhf&_nc_ht=scontent-lax3-2.xx&oh=00_AfBkCkQa2bzq7KgLlKzsl2Ke7XZbrxdh0ASvnvwTrUi9_A&oe=66077BB2',
#   'insight': True,
#   'first_gen': True,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2011 HONDA INSIGHT HYBRID PART OUT STK#220325',
#   'price': 555,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/377914535218527/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/432999210_25026911693620187_3447727108352127682_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=101&ccb=1-7&_nc_sid=247b10&_nc_ohc=wXpygNE7_RQAX99hxDO&_nc_oc=Adh9HKIwSRAoKtKAJqY03oCUWwshvL-y4yT-q4X-_qNVxnK16iOaCjDnz9DwQBSZBfQ&_nc_ht=scontent-lax3-2.xx&oh=00_AfApbPNe6U2h30V7eGF3Cj_aYhNgOQcACLd1q-OdmB-mSg&oe=6606ABB2',
#   'insight': True,
#   'first_gen': False,
#   'parts': True,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight LX Hatchback 4D',
#   'price': 3650,
#   'city': 'Petaluma',
#   'state': 'CA',
#   'mileage': 215000,
#   'url': 'https://www.facebook.com/marketplace/item/726291939237098/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/419512314_1608498716642061_528603107770901472_n.jpg?stp=c0.318.828.828a_dst-jpg_s261x260&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&_nc_ohc=f5jElRYVQ3wAX8XUVmX&_nc_ht=scontent-lax3-1.xx&oh=00_AfBIcwPT6ujB8SP4bRwouTzMymtflHUt7F_N9OGYA7Y6QA&oe=66068129',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2015 Honda civic LX Sedan 4D',
#   'price': 10900,
#   'city': 'Millbrae',
#   'state': 'CA',
#   'mileage': 105000,
#   'url': 'https://www.facebook.com/marketplace/item/1525647477983851/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/434301842_1082609526363547_5371713515124546838_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=101&ccb=1-7&_nc_sid=5f2048&_nc_ohc=8B_V_0h_76gAX8mwf-j&_nc_ht=scontent-lax3-2.xx&oh=00_AfCSHBnrF6XwimsSMTBYQUtd6Fk06jm0-cGDSTMj4jfiFw&oe=66070D29',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2011 honda crz',
#   'price': 4000,
#   'city': 'Concord',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/2357554687777560/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/431009167_7128622337193058_4404202410112314263_n.jpg?stp=c33.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=247b10&_nc_ohc=MkHal_j8sZIAX8RYbgr&_nc_ht=scontent-lax3-2.xx&oh=00_AfClImseiaQoeIRxfB1MR2d414yed-7f7b_eA4saMyv6Aw&oe=6606F71E',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 HONDA INSIGHT PART OUT STK#220481',
#   'price': 555,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/1905259313263626/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/428102920_6938632332925364_5002419423424689497_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=247b10&_nc_ohc=UMJtw4xaAa4AX-pKT9R&_nc_ht=scontent-lax3-2.xx&oh=00_AfBCW3bnHjNScsDZs_qEM03uAXqiEMjoWcFcJepjmplFTQ&oe=660664E9',
#   'insight': True,
#   'first_gen': False,
#   'parts': True,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2020 Toyota corolla LE Sedan 4D',
#   'price': 10300,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 85000,
#   'url': 'https://www.facebook.com/marketplace/item/1619154685565918/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/420182650_7503094406424761_7276910086081524553_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=103&ccb=1-7&_nc_sid=5f2048&_nc_ohc=e8v9jxENa2EAX-httQw&_nc_ht=scontent-lax3-2.xx&oh=00_AfA1KdeF0yUybApl85sjorgBZW54pWi7uO5-Fn3Z7O-r2g&oe=66062B60',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 HONDA INSIGHT PART OUT STK #220368',
#   'price': 555,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/3779386838951976/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/333515839_6440748032661262_7087570814155921499_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=108&ccb=1-7&_nc_sid=247b10&_nc_ohc=jrTEZ0fnUn4AX_UQDQr&_nc_ht=scontent-lax3-1.xx&oh=00_AfDXaNDpsp-xNMqu9tVXi3nx2sA3iR80qKur-yAiqo0mmQ&oe=66077315',
#   'insight': True,
#   'first_gen': False,
#   'parts': True,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight LX Hatchback 4D',
#   'price': 4050,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 179000,
#   'url': 'https://www.facebook.com/marketplace/item/1350974868911535/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/428390860_7966588370036012_1510201322359394701_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=MTBBz_3CkEMAX9e_q2E&_nc_ht=scontent-lax3-2.xx&oh=00_AfBiHPaQUjUTII4fK2T6TELLYEDnZfmK7w5k1uOgCpjvOg&oe=6607C635',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda Clarity Plug-in Hybrid',
#   'price': 14800,
#   'city': 'Modesto',
#   'state': 'CA',
#   'mileage': 45000,
#   'url': 'https://www.facebook.com/marketplace/item/768193044753003/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/427856302_3565044860416816_4528265146180168416_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=109&ccb=1-7&_nc_sid=5f2048&_nc_ohc=p-MmuOir4c4AX9A2x0o&_nc_ht=scontent-lax3-1.xx&oh=00_AfBp_fGtGuDLuaeu0ZEkg7EYCyr8qLnFDIsX60ZB1wC3XA&oe=6606A708',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2012 Honda insight',
#   'price': 7300,
#   'city': 'Daly City',
#   'state': 'CA',
#   'mileage': 188000,
#   'url': 'https://www.facebook.com/marketplace/item/1125725482196921/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/431247658_10225160688387071_3529572508475670981_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=102&ccb=1-7&_nc_sid=5f2048&_nc_ohc=08qyKmh4kd0AX-L7odO&_nc_ht=scontent-lax3-1.xx&oh=00_AfBiUCuPTd9wm5YhF-GxK3z7AKZDYonl2TOnJjL06SLZ4Q&oe=6606B023',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2021 Honda insight EX Sedan 4D',
#   'price': 18000,
#   'city': 'Tracy',
#   'state': 'CA',
#   'mileage': 38000,
#   'url': 'https://www.facebook.com/marketplace/item/3278926715744855/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/424582740_122095170728217061_8922968627428282385_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&_nc_ohc=Aoy7Ud1AS7cAX-glmJK&_nc_ht=scontent-lax3-1.xx&oh=00_AfAZNNz4RQqEtPKrawNYXO3SMOEIQUvxyp3llQj11jek9g&oe=66078B94',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2011 Honda cr-z EX Coupe 2D',
#   'price': 8000,
#   'city': 'Brisbane',
#   'state': 'CA',
#   'mileage': 117000,
#   'url': 'https://www.facebook.com/marketplace/item/292392320374031/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/429965797_7194502594002939_4142912142824030860_n.jpg?stp=c0.101.261.261a_dst-jpg_p261x260&_nc_cat=101&ccb=1-7&_nc_sid=247b10&_nc_ohc=oFtM8F7wxWUAX_zbMAh&_nc_ht=scontent-lax3-2.xx&oh=00_AfC4kgM8SZ63PRUhZUmQcU1iGr6MlXBwGU7VTAiHAI3DLQ&oe=66061F4A',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2012 Honda insight',
#   'price': 4700,
#   'city': 'Los Angeles',
#   'state': 'CA',
#   'mileage': 210000,
#   'url': 'https://www.facebook.com/marketplace/item/7712630535448480/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/434127596_393125533658990_6128696779768187837_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=102&ccb=1-7&_nc_sid=5f2048&_nc_ohc=oXUhgaT6UyoAX-1lsEa&_nc_ht=scontent-lax3-1.xx&oh=00_AfCbXQwc-6-L4IaMqtr_EhulJJ9dTAiTFS8pNaNG19JmJg&oe=660606BF',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2005 Honda insight',
#   'price': 1500,
#   'city': 'Redwood City',
#   'state': 'CA',
#   'mileage': 209000,
#   'url': 'https://www.facebook.com/marketplace/item/1906404689773974/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/423955995_7572329789478085_7582290326726139747_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=247b10&_nc_ohc=X96g0CYWA7IAX-tGICl&_nc_ht=scontent-lax3-2.xx&oh=00_AfD-OleuiypLcMRjhfmWMbEIcJqcNcSKtQklveNVw22RwQ&oe=6606D1B4',
#   'insight': True,
#   'first_gen': True,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2023 Honda civic EX 1.5T',
#   'price': 18900,
#   'city': 'Stockton',
#   'state': 'CA',
#   'mileage': 9000,
#   'url': 'https://www.facebook.com/marketplace/item/1573977209809567/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/434191253_365437926466550_1955523981046919648_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=108&ccb=1-7&_nc_sid=5f2048&_nc_ohc=PeR9uUDiursAX_lAYs1&_nc_ht=scontent-lax3-1.xx&oh=00_AfBQT8gdxRa2A-6Mkgo_fc2GFV2j-ZQ_bBGphjvxyoZJlA&oe=6606D24B',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Hyundai ioniq hybrid Híbrido',
#   'price': 8999,
#   'city': 'Milpitas',
#   'state': 'CA',
#   'mileage': 98000,
#   'url': 'https://www.facebook.com/marketplace/item/3699307250392062/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/432000149_7583449218383452_356153905837751294_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=100&ccb=1-7&_nc_sid=5f2048&_nc_ohc=I8Okj_ZvSfQAX-Oqa4-&_nc_ht=scontent-lax3-2.xx&oh=00_AfAPK4Knos1WfIShP42OSeZZ_6sUjLhOKl1lFTTTWCP75A&oe=660716B0',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': 'parting a 2014 honda  insight',
#   'price': 3500,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/390440863732310/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/431751896_25524302337157029_9191828418949536111_n.jpg?stp=c44.0.260.260a_dst-jpg_p261x260&_nc_cat=107&ccb=1-7&_nc_sid=247b10&_nc_ohc=p3DkdP57EqQAX8icS_s&_nc_ht=scontent-lax3-2.xx&oh=00_AfB5sT0IbrUvm4MkFAvfivlYUVL9WRCSqV-Qm-0xmXS4Ig&oe=66072E19',
#   'insight': True,
#   'first_gen': False,
#   'parts': True,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda Clarity Plug-in Hybrid',
#   'price': 18800,
#   'city': 'Fremont',
#   'state': 'CA',
#   'mileage': 38000,
#   'url': 'https://www.facebook.com/marketplace/item/1823457578114248/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/430086529_6991156537679630_171828198181775111_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=100&ccb=1-7&_nc_sid=5f2048&_nc_ohc=WkRgBEpXzWQAX_uNEjZ&_nc_ht=scontent-lax3-2.xx&oh=00_AfDNevQYJeKPAY2bW2MudWDO5BSk23-ojPe0fNGZeQswZg&oe=6605E92C',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight LX Hatchback 4D',
#   'price': 4500,
#   'city': 'Portola Valley',
#   'state': 'CA',
#   'mileage': 257000,
#   'url': 'https://www.facebook.com/marketplace/item/900063445143750/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6

#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight',
#   'price': 7500,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 91000,
#   'url': 'https://www.facebook.com/marketplace/item/1034616914290734/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/423162520_7039370682794981_6111613321677866849_n.jpg?stp=c0.9.261.261a_dst-jpg_p261x260&_nc_cat=108&ccb=1-7&_nc_sid=5f2048&_nc_ohc=wWoHP2wu19gAX9OxO0l&_nc_ht=scontent-lax3-1.xx&oh=00_AfC2_JKuk9bROpugWWLwlDb2VD9RNoNOrep2_-U7Wo_Dsg&oe=6607BAA1',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda hr-v EX Sport Utility 4D',
#   'price': 12000,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 59000,
#   'url': 'https://www.facebook.com/marketplace/item/833731478772768/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/418834660_1978055082590527_4989112732115524443_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=100&ccb=1-7&_nc_sid=5f2048&_nc_ohc=g5wY9OtmolgAX9wOISa&_nc_ht=scontent-lax3-2.xx&oh=00_AfB5IiGteVs-sP53LRTgcc3EUF6kPfFVOYSVAU6cV6jVew&oe=660677BE',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight',
#   'price': 5500,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 190000,
#   'url': 'https://www.facebook.com/marketplace/item/1468833920512972/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/429590551_2709724642499657_8541493129476657289_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=103&ccb=1-7&_nc_sid=5f2048&_nc_ohc=rzj-hxq_7LAAX-rpsQs&_nc_ht=scontent-lax3-2.xx&oh=00_AfA6S33cCePfGD9oYA8jUzVxfASm8zGnb3MCyQQi7JPKEA&oe=6606EAB5',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2020 Honda insight EX Sedan 4D',
#   'price': 22961,
#   'city': 'Hayward',
#   'state': 'CA',
#   'mileage': 61000,
#   'url': 'https://www.facebook.com/marketplace/item/743590754163500/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/417566143_122144130314075939_6125760895579188149_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&_nc_ohc=PI7ICjHBTSMAX_1N6n1&_nc_oc=AdjSAav1bFhnvwAsq0gu8y_71Y_CZDgkXe8L1lNhvG127ieV1oowjwA37AoTWRIf8Ew&_nc_ht=scontent-lax3-1.xx&oh=00_AfCdaoLFb_lW0CRzqDiALNdyBIX_Csqe9Q5yBsToXmZJKw&oe=6607B04B',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2021 Honda insight',
#   'price': 18299,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 47000,
#   'url': 'https://www.facebook.com/marketplace/item/413689324404279/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t45.5328-4/430920487_7354627211273280_8200020051055315554_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=100&ccb=1-7&_nc_sid=247b10&_nc_ohc=m61Spz73VEoAX9NLuSq&_nc_ht=scontent-lax3-2.xx&oh=00_AfAA1KYQEQke-agF1qzz43lukPxhTgxyXsbGKCVSEtjyZg&oe=66072B95',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2020 Honda accord hybrid Touring Sedan 4D',
#   'price': 20000,
#   'city': 'Orangevale',
#   'state': 'CA',
#   'mileage': 22000,
#   'url': 'https://www.facebook.com/marketplace/item/403698715652061/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
# ...
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2013 Honda insight Hatchback 4D',
#   'price': 8000,
#   'city': 'Stockton',
#   'state': 'CA',
#   'mileage': 121000,
#   'url': 'https://www.facebook.com/marketplace/item/2138970696461961/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/431574982_411232328168815_6793337601403536650_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=6a7IHrWzm7EAX8NNHb_&_nc_ht=scontent-lax3-2.xx&oh=00_AfBr010EhOP3c5UjAuiuub36WvPIVmQgEBMaT_pUm0skZA&oe=6606A5ED',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2021 Honda insight',
#   'price': 13500,
#   'city': 'Manteca',
#   'state': 'CA',
#   'mileage': 184000,
#   'url': 'https://www.facebook.com/marketplace/item/303808515702329/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/429671536_122119460630215030_1630756983150616521_n.jpg?stp=c52.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=le6WC_g-MokAX-Sj6Ir&_nc_ht=scontent-lax3-2.xx&oh=00_AfCkRxDzN4tsE3eEl6oypjNsE5ctzTbeBE0CVgBvksEYxg&oe=66071D24',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2022 Honda accord hybrid Sport Sedan 4D',
#   'price': 22999,
#   'city': 'Clayton',
#   'state': 'CA',
#   'mileage': 28000,
#   'url': 'https://www.facebook.com/marketplace/item/788382319828489/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/432769497_272091869272071_944432964533722345_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=105&ccb=1-7&_nc_sid=5f2048&_nc_ohc=hmZwQqxMfkwAX-ncIeR&_nc_ht=scontent-lax3-1.xx&oh=00_AfC3bJyVJBgLlnjh-9qoS2H6iLGT9mKuCah0hU-NnCfetg&oe=6606E2E2',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight EX Hatchback 4D',
#   'price': 6800,
#   'city': 'Manteca',
#   'state': 'CA',
#   'mileage': 154000,
#   'url': 'https://www.facebook.com/marketplace/item/362982763334192/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/426563347_3654797334809103_4849426268254994239_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=101&ccb=1-7&_nc_sid=5f2048&_nc_ohc=9wmmdtQ97JEAX8ztO1v&_nc_ht=scontent-lax3-2.xx&oh=00_AfCFjg0fZ3bucKQB6aoJ6zG3Z1EJHUdJ8qEErhqtMa_Kmg&oe=6606251A',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2017 Toyota prius c',
#   'price': 10500,
#   'city': 'Oakland',
#   'state': 'CA',
#   'mileage': 84000,
#   'url': 'https://www.facebook.com/marketplace/item/392351243526568/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/430752904_7252932408156256_6492374139653409129_n.jpg?stp=c101.0.260.260a_dst-jpg_p261x260&_nc_cat=105&ccb=1-7&_nc_sid=247b10&_nc_ohc=t089WK_SiS8AX-urPwd&_nc_ht=scontent-lax3-1.xx&oh=00_AfBG8TuTod4TJuKByhBq9PgKedz0KQoR4LSxWTJpgzVORw&oe=6606F4A5',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight EX Hatchback 4D',
#   'price': 7500,
#   'city': 'Santa Clara',
#   'state': 'CA',
#   'mileage': 150000,
#   'url': 'https://www.facebook.com/marketplace/item/757611509634479/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/427968733_10161467824826130_4094132563309073998_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=110&ccb=1-7&_nc_sid=5f2048&_nc_ohc=vKbIw0S6aMoAX_EQJYo&_nc_ht=scontent-lax3-1.xx&oh=00_AfAMuqELAfZJVESM5WQ9FRiFOJ3qEWOXxw_p22SsMWROXA&oe=66061B5A',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda Accord Hybrid',
#   'price': 26000,
#   'city': 'Milpitas',
#   'state': 'CA',
#   'mileage': 37000,
#   'url': 'https://www.facebook.com/marketplace/item/1093725425269178/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/431558254_1463177717889328_795461546599430560_n.jpg?stp=c0.43.261.261a_dst-jpg_p261x260&_nc_cat=109&ccb=1-7&_nc_sid=247b10&_nc_ohc=0ehZd2jujWYAX_WosqT&_nc_ht=scontent-lax3-1.xx&oh=00_AfAtgnWGOZBExI7LkveCTP2w1XI7lt_76zOPLXkLoQzELA&oe=66073CF3',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2022 Honda insight EX Sedan 4D',
#   'price': 18350,
#   'city': 'Citrus Heights',
#   'state': 'CA',
#   'mileage': 53000,
#   'url': 'https://www.facebook.com/marketplace/item/791640382999780/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/432748114_122094423014249679_3008048896876101321_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=XomHM6TPY1AAX-o92NV&_nc_ht=scontent-lax3-2.xx&oh=00_AfDp5STPF8HZon7Iv8dypHALpsB61EoA9-5Emv3kF3HJWg&oe=66068CFA',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2015 Toyota prius Three Hatchback 4D',
#   'price': 12888,
#   'city': 'Millbrae',
#   'state': 'CA',
#   'mileage': 49000,
#   'url': 'https://www.facebook.com/marketplace/item/308723631958159/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/434057149_10232665006666723_6308358620972901675_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=100&ccb=1-7&_nc_sid=5f2048&_nc_ohc=siV_6yBFJfMAX9hqB0i&_nc_ht=scontent-lax3-2.xx&oh=00_AfDcOYvhLOefvXo8Y9GkswmbvuLeQ8unmtfenyElOAjqyw&oe=66079DF3',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2019 Honda insight Touring Sedan 4D',
#   'price': 19775,
#   'city': 'Willows',
#   'state': 'CA',
#   'mileage': 87000,
#   'url': 'https://www.facebook.com/marketplace/item/415897330894453/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/426240482_6721016281335920_1113770730168005122_n.jpg?stp=c52.0.260.260a_dst-jpg_p261x260&_nc_cat=110&ccb=1-7&_nc_sid=247b10&_nc_ohc=axjMMo-_CH0AX9VGuot&_nc_ht=scontent-lax3-1.xx&oh=00_AfC4Ftj9R4tidaglMsmZw5N27WBZGbCE0X0-Xqf2Tji8mA&oe=6607228C',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2014 BMW i3 Range Extender Hatchback 4D',
#   'price': 9900,
#   'city': 'Roseville',
#   'state': 'CA',
#   'mileage': 68000,
#   'url': 'https://www.facebook.com/marketplace/item/1866899427079734/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/417528734_7263161083732243_1047661115547114322_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=tRaj1ugNGGIAX_aE42u&_nc_ht=scontent-lax3-2.xx&oh=00_AfCAEzrsCpoLVVkFbnaR5MczGLYcpBLmw6HQSz3ks4vk-w&oe=660776EF',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight EX Hatchback 4D',
#   'price': 6899,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 120000,
#   'url': 'https://www.facebook.com/marketplace/item/3787311621498631/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/429437847_7160004577387781_3548152757866654466_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=108&ccb=1-7&_nc_sid=247b10&_nc_ohc=hub0rQKjZBYAX8U2fVG&_nc_ht=scontent-lax3-1.xx&oh=00_AfBvFvOUJbcqdWY7tbWqEYcKT2y694Dbi8C_J53xaUC6lA&oe=6605E992',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2021 Honda insight',
#   'price': 19500,
#   'city': 'San Jose',
#   'state': 'CA',
#   'mileage': 4000,
#   'url': 'https://www.facebook.com/marketplace/item/1138347274193874/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/427850469_1745405062616606_8232181557499426771_n.jpg?stp=c58.0.260.260a_dst-jpg_p261x260&_nc_cat=102&ccb=1-7&_nc_sid=5f2048&_nc_ohc=Jn_L8LowNIgAX9MbtVZ&_nc_ht=scontent-lax3-1.xx&oh=00_AfAWGL7tvEWdkxaY067CHcirPO6LjkAM63MxTvMyhHEk7g&oe=66079B39',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2013 Honda insight',
#   'price': 11910,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 43000,
#   'url': 'https://www.facebook.com/marketplace/item/648908380598736/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/397933037_6764883986893160_8158603709685048641_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=109&ccb=1-7&_nc_sid=247b10&_nc_ohc=PZhtErHgWVwAX8u2IPv&_nc_ht=scontent-lax3-1.xx&oh=00_AfCyu8nh5KyvxfWJ6y6JuDXheU_ISvpCq4Ui7uOS6_NePg&oe=6607B321',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2013 Toyota prius Four Hatchback 4D',
#   'price': 10500,
#   'city': 'Concord',
#   'state': 'CA',
#   'mileage': 86000,
#   'url': 'https://www.facebook.com/marketplace/item/277268032085486/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/420181102_2606199999553987_2952176845822702365_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=102&ccb=1-7&_nc_sid=5f2048&_nc_ohc=NmdtpsSMPNYAX-POIzW&_nc_ht=scontent-lax3-1.xx&oh=00_AfAbRyvk9uqsz-V15T_7P3DtdNogSf-axfCQCXMiKNsd0Q&oe=66065CDD',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2010 Honda insight EX Hatchback 4D',
#   'price': 6000,
#   'city': 'Watsonville',
#   'state': 'CA',
#   'mileage': 212000,
#   'url': 'https://www.facebook.com/marketplace/item/803025134694403/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/361401407_232894306249820_8078772612298229586_n.jpg?stp=c101.0.260.260a_dst-jpg_p261x260&_nc_cat=107&ccb=1-7&_nc_sid=5f2048&_nc_ohc=DtP97M0MMxwAX9IwdLL&_nc_ht=scontent-lax3-2.xx&oh=00_AfBkCrliM_vV1TX7llPUl2HeZs4KqtdSU3GADxNAZfCmWA&oe=66062660',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2019 Hyundai Ioniq Plug-in Hybrid',
#   'price': 12900,
#   'city': 'Tracy',
#   'state': 'CA',
#   'mileage': 117000,
#   'url': 'https://www.facebook.com/marketplace/item/1738275910028556/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/433720146_2201039136902578_4003063894116367383_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=110&ccb=1-7&_nc_sid=5f2048&_nc_ohc=pbVmpODGEn8AX_CtPIf&_nc_ht=scontent-lax3-1.xx&oh=00_AfDiGg5zz8CLDemUSxS-YwCFNccwHd6H4EufuP7fM0cD_A&oe=6605EEFE',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': 'Honda Insight Hybrid Battery',
#   'price': 550,
#   'city': 'San Francisco',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/354494347421800/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/419870791_7148727621851436_459547149615764002_n.jpg?stp=c41.0.260.260a_dst-jpg_p261x260&_nc_cat=110&ccb=1-7&_nc_sid=247b10&_nc_ohc=VP2Sbd1aTTYAX9X6kTU&_nc_ht=scontent-lax3-1.xx&oh=00_AfDAYr6c0x1ESwHzP0kVs-wZyPUR7YYiA4xlimQeO-TGXA&oe=66065EEC',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2016 Honda hr-v EX Sport Utility 4D',
#   'price': 12500,
#   'city': 'Richmond',
#   'state': 'CA',
#   'mileage': 78000,
#   'url': 'https://www.facebook.com/marketplace/item/1570960393651260/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-2.xx.fbcdn.net/v/t39.30808-6/434304690_7449674588431946_4187516809581535316_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=106&ccb=1-7&_nc_sid=5f2048&_nc_ohc=ENZjN0WPltUAX8VPcCU&_nc_ht=scontent-lax3-2.xx&oh=00_AfDcfOzeIyH6MOdyv5KaMo7Gdb_PCllDcQIFBqUsT1avZw&oe=66079B83',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2011 Honda insight LX Hatchback 4D',
#   'price': 99,
#   'city': 'Rancho Cordova',
#   'state': 'CA',
#   'mileage': 999000,
#   'url': 'https://www.facebook.com/marketplace/item/761864612467463/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/422123157_122128203224102499_417188138567034488_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=104&ccb=1-7&_nc_sid=5f2048&_nc_ohc=SN7A9z7ZDEUAX9y_jlS&_nc_ht=scontent-lax3-1.xx&oh=00_AfCbvJ4-ztg6IO74ExPXVVE74qawqlLbtxPqXxGYaL22Pw&oe=66065B47',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda accord LX',
#   'price': 4000,
#   'city': 'Sacramento',
#   'state': 'CA',
#   'mileage': 81000,
#   'url': 'https://www.facebook.com/marketplace/item/760039866102713/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/432110758_773234611426657_323415110007333850_n.jpg?stp=c43.0.260.260a_dst-jpg_p261x260&_nc_cat=105&ccb=1-7&_nc_sid=247b10&_nc_ohc=5j8clXeGNfwAX-hxNF6&_nc_ht=scontent-lax3-1.xx&oh=00_AfC2prkk_nprwtg4yKnj31OoyTiEV2opNpmxjANIYMANcQ&oe=66070C26',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': 'honda insight grill 2012-14',
#   'price': 145,
#   'city': 'Newark',
#   'state': 'CA',
#   'mileage': 0,
#   'url': 'https://www.facebook.com/marketplace/item/811483757703711/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t45.5328-4/432053485_7225559284196310_5927986164719675879_n.jpg?stp=c151.0.260.260a_dst-jpg_p261x260&_nc_cat=104&ccb=1-7&_nc_sid=247b10&_nc_ohc=WbvT-s2yd-8AX_vmXBs&_nc_ht=scontent-lax3-1.xx&oh=00_AfCFpZ6yiNkakMUVln8MqDGVmrt4XPHjhfKe_op_D70K8g&oe=660762E9',
#   'insight': True,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'},
#  {'date': datetime.date(2024, 3, 25),
#   'title': '2018 Honda accord LX Sedan 4D',
#   'price': 12000,
#   'city': 'Stockton',
#   'state': 'CA',
#   'mileage': 55000,
#   'url': 'https://www.facebook.com/marketplace/item/1186100065709654/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'image': 'https://scontent-lax3-1.xx.fbcdn.net/v/t39.30808-6/428609727_391640620484525_7244974212788399962_n.jpg?stp=c0.29.261.261a_dst-jpg_p261x260&_nc_cat=109&ccb=1-7&_nc_sid=5f2048&_nc_ohc=DJ9ZBtMWSxwAX93A0fK&_nc_ht=scontent-lax3-1.xx&oh=00_AfDFagz7YYIzZKYLDidnwiu3LY6rAHuhjP1kPAyzPf8lLQ&oe=66062B6A',
#   'insight': False,
#   'first_gen': False,
#   'parts': False,
#   'site': 'fb'}]

# %%
vehicles_df = pd.DataFrame(vehicles_list)

# %%
vehicles_df
# Out:
#            date                                   title  price  \
# 0    2024-03-25  2002 Honda insight Hybrid Hatchback 2D   3950
# 1    2024-03-25         2012 Honda insight Hatchback 4D   6400
# 2    2024-03-25      2010 Honda insight EX Hatchback 4D   4500
# 3    2024-03-25          2020 Honda insight EX Sedan 4D  11900
# 4    2024-03-25     2019 Honda insight Touring Sedan 4D  15500
# ..          ...                                     ...    ...
# 115  2024-03-25     2016 Honda hr-v EX Sport Utility 4D  12500
# 116  2024-03-25      2011 Honda insight LX Hatchback 4D     99
# 117  2024-03-25                    2018 Honda accord LX   4000
# 118  2024-03-25             honda insight grill 2012-14    145
# 119  2024-03-25           2018 Honda accord LX Sedan 4D  12000
#
#                city state  mileage  \
# 0     San Francisco    CA   165000
# 1          San Jose    CA   125000
# 2           Fremont    CA   183000
# 3          San Jose    CA   110000
# 4        Carmichael    CA    49000
# ..              ...   ...      ...
# 115        Richmond    CA    78000
# 116  Rancho Cordova    CA   999000
# 117      Sacramento    CA    81000
# 118          Newark    CA        0
# 119        Stockton    CA    55000
#
#                                                    url  \
# 0    https://www.facebook.com/marketplace/item/1492...
# 1    https://www.facebook.com/marketplace/item/4260...
# 2    https://www.facebook.com/marketplace/item/3136...
# 3    https://www.facebook.com/marketplace/item/7311...
# 4    https://www.facebook.com/marketplace/item/2727...
# ..                                                 ...
# 115  https://www.facebook.com/marketplace/item/1570...
# 116  https://www.facebook.com/marketplace/item/7618...
# 117  https://www.facebook.com/marketplace/item/7600...
# 118  https://www.facebook.com/marketplace/item/8114...
# 119  https://www.facebook.com/marketplace/item/1186...
#
#                                                  image  insight  first_gen  \
# 0    https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...     True       True
# 1    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 2    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 3    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 4    https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...     True      False
# ..                                                 ...      ...        ...
# 115  https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...    False      False
# 116  https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 117  https://scontent-lax3-1.xx.fbcdn.net/v/t45.532...    False      False
# 118  https://scontent-lax3-1.xx.fbcdn.net/v/t45.532...     True      False
# 119  https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...    False      False
#
#      parts site
# 0    False   fb
# 1    False   fb
# 2    False   fb
# 3    False   fb
# 4    False   fb
# ..     ...  ...
# 115  False   fb
# 116  False   fb
# 117  False   fb
# 118  False   fb
# 119  False   fb
#
# [120 rows x 12 columns]

# %%
filtered_df = vehicles_df[vehicles_df['insight']==True]

# %%
filtered_df
# Out:
#            date                                   title  price  \
# 0    2024-03-25  2002 Honda insight Hybrid Hatchback 2D   3950
# 1    2024-03-25         2012 Honda insight Hatchback 4D   6400
# 2    2024-03-25      2010 Honda insight EX Hatchback 4D   4500
# 3    2024-03-25          2020 Honda insight EX Sedan 4D  11900
# 4    2024-03-25     2019 Honda insight Touring Sedan 4D  15500
# ..          ...                                     ...    ...
# 110  2024-03-25                      2013 Honda insight  11910
# 112  2024-03-25      2010 Honda insight EX Hatchback 4D   6000
# 114  2024-03-25            Honda Insight Hybrid Battery    550
# 116  2024-03-25      2011 Honda insight LX Hatchback 4D     99
# 118  2024-03-25             honda insight grill 2012-14    145
#
#                city state  mileage  \
# 0     San Francisco    CA   165000
# 1          San Jose    CA   125000
# 2           Fremont    CA   183000
# 3          San Jose    CA   110000
# 4        Carmichael    CA    49000
# ..              ...   ...      ...
# 110      Sacramento    CA    43000
# 112     Watsonville    CA   212000
# 114   San Francisco    CA        0
# 116  Rancho Cordova    CA   999000
# 118          Newark    CA        0
#
#                                                    url  \
# 0    https://www.facebook.com/marketplace/item/1492...
# 1    https://www.facebook.com/marketplace/item/4260...
# 2    https://www.facebook.com/marketplace/item/3136...
# 3    https://www.facebook.com/marketplace/item/7311...
# 4    https://www.facebook.com/marketplace/item/2727...
# ..                                                 ...
# 110  https://www.facebook.com/marketplace/item/6489...
# 112  https://www.facebook.com/marketplace/item/8030...
# 114  https://www.facebook.com/marketplace/item/3544...
# 116  https://www.facebook.com/marketplace/item/7618...
# 118  https://www.facebook.com/marketplace/item/8114...
#
#                                                  image  insight  first_gen  \
# 0    https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...     True       True
# 1    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 2    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 3    https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 4    https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...     True      False
# ..                                                 ...      ...        ...
# 110  https://scontent-lax3-1.xx.fbcdn.net/v/t45.532...     True      False
# 112  https://scontent-lax3-2.xx.fbcdn.net/v/t39.308...     True      False
# 114  https://scontent-lax3-1.xx.fbcdn.net/v/t45.532...     True      False
# 116  https://scontent-lax3-1.xx.fbcdn.net/v/t39.308...     True      False
# 118  https://scontent-lax3-1.xx.fbcdn.net/v/t45.532...     True      False
#
#      parts site
# 0    False   fb
# 1    False   fb
# 2    False   fb
# 3    False   fb
# 4    False   fb
# ..     ...  ...
# 110  False   fb
# 112  False   fb
# 114  False   fb
# 116  False   fb
# 118  False   fb
#
# [67 rows x 12 columns]

# %%
csv_file_path = f'/Users/evanishibashi/Projects/insight/csv/fb/{date.today()}.csv'

filtered_df.to_csv(csv_file_path, index=False)
